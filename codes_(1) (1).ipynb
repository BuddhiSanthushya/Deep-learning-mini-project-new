# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/mini project 1/")
os.getcwd()

img = image.load_img("Training/a/a.1.jpeg")

plt.imshow(img)

cv2.imread("Training/ka/ka.1.jpeg").shape

train = ImageDataGenerator(rescale = 1/255)

validation = ImageDataGenerator(rescale = 1/255)

train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')

train_dataset.class_indices

train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])



model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)


validation_dataset.class_indices

dir_path = 'Testing/'

for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()

  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'a' in Sinhala")
  else:
    print("This is Letter 'ka' in Sinhala")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 91s 22s/step - loss: 26.5067 - accuracy: 0.3077 - val_loss: 1.5130 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 7s 1s/step - loss: 1.1420 - accuracy: 0.4667 - val_loss: 0.7189 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.8581 - accuracy: 0.6000 - val_loss: 1.2340 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.9274 - accuracy: 0.4615 - val_loss: 0.7299 - val_accuracy: 0.5000
# Epoch 5/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.8912 - accuracy: 0.4667 - val_loss: 0.6450 - val_accuracy: 0.8700
# Epoch 6/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7336 - accuracy: 0.5333 - val_loss: 0.6460 - val_accuracy: 0.5800
# Epoch 7/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6833 - accuracy: 0.5333 - val_loss: 0.6103 - val_accuracy: 0.5100
# Epoch 8/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7043 - accuracy: 0.4667 - val_loss: 0.5819 - val_accuracy: 0.5900
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4404 - accuracy: 0.8000 - val_loss: 1.9955 - val_accuracy: 0.5000
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 1.0933 - accuracy: 0.6000 - val_loss: 0.4833 - val_accuracy: 0.8500
# Epoch 11/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3541 - accuracy: 0.9333 - val_loss: 0.7496 - val_accuracy: 0.6900
# Epoch 12/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.5070 - accuracy: 0.8000 - val_loss: 0.3671 - val_accuracy: 0.8500
# Epoch 13/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3477 - accuracy: 0.9333 - val_loss: 0.5161 - val_accuracy: 0.7700
# Epoch 14/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.4784 - accuracy: 0.7333 - val_loss: 0.3196 - val_accuracy: 0.8600
# Epoch 15/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6158 - accuracy: 0.8000 - val_loss: 0.4356 - val_accuracy: 0.8700
# Epoch 16/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.2422 - accuracy: 0.9333 - val_loss: 0.2478 - val_accuracy: 0.8800
# Epoch 17/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2582 - accuracy: 0.8667 - val_loss: 0.4785 - val_accuracy: 0.8000
# Epoch 18/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6397 - accuracy: 0.6667 - val_loss: 0.1937 - val_accuracy: 0.9300
# Epoch 19/30
# 5/5 [==============================] - 6s 1s/step - loss: 2.4064 - accuracy: 0.7333 - val_loss: 0.2490 - val_accuracy: 0.9200
# Epoch 20/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2264 - accuracy: 0.8667 - val_loss: 0.1924 - val_accuracy: 0.9300
# Epoch 21/30
# 5/5 [==============================] - 4s 978ms/step - loss: 0.2452 - accuracy: 0.8000 - val_loss: 0.1837 - val_accuracy: 0.9400
# Epoch 22/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2104 - accuracy: 0.8667 - val_loss: 0.2101 - val_accuracy: 0.9200
# Epoch 23/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0933 - accuracy: 0.9333 - val_loss: 0.2097 - val_accuracy: 0.9300
# Epoch 24/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1400 - accuracy: 0.9333 - val_loss: 0.1823 - val_accuracy: 0.9400
# Epoch 25/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.3352 - accuracy: 0.8667 - val_loss: 0.1548 - val_accuracy: 0.9500
# Epoch 26/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9500
# Epoch 27/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3475 - accuracy: 0.8462 - val_loss: 0.1789 - val_accuracy: 0.9100
# Epoch 28/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.4630 - accuracy: 0.8667 - val_loss: 0.2282 - val_accuracy: 0.9300
# Epoch 29/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9000
# Epoch 30/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2033 - accuracy: 0.8667 - val_loss: 0.1307 - val_accuracy: 0.9500
# 1/1 [==============================] - 0s 216ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 50ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 50ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 47ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 57ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 49ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 68ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 79ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 56ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 58ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 47ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 42ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 42ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 50ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 45ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 45ms/step
# This is Letter 'a' in Sinhala
# 1/1 [==============================] - 0s 61ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 61ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 64ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 68ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'ka' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'ka' in Sinhala
